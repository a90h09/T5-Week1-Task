# %% [markdown]
# <a href="https://colab.research.google.com/github/a90h09/T5-Week1-Task/blob/main/Task_(1)_Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dataset Description

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# *   Name : Ahmed Abdullah Bashmmakh
# *   Group : 10

# %% [markdown]
# # Tasks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
df = pd.read_csv('/content/Task (1) Dataset.csv')
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.shape
# Out:
# (12316, 32)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
# using forward fill
df.fillna(method='ffill',inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
# 5  14:15:00      Friday              31-50          Male  Junior high school
# 6  17:30:00   Wednesday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr  Public (> 45 seats)
# 5                 Unknown              2-5yr  Public (> 45 seats)
# 6                Employee              2-5yr           Automobile
# 7                Employee              2-5yr           Automobile
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.shape
# Out:
# (12313, 32)

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
df['Sex_of_driver'] = df['Sex_of_driver'].replace({'na': 'Male'})
df['Accident_severity'] = df['Accident_severity'].replace({'Slight Injury': 'Slight injury'})
df['Accident_severity'] = df['Accident_severity'].replace({'Serious Injury': 'Serious injury'})

# %%
print(df['Accident_severity'].unique())
print(df['Age_band_of_driver'].unique())
print(df['Sex_of_driver'].unique())
print(df['Educational_level'].unique())
print(df['Vehicle_driver_relation'].unique())
# Out:
# ['Slight injury' 'Serious injury' 'Fatal injury']
# ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
# ['Male' 'Female' 'Unknown']
# ['Junior high school' 'Above high school' 'Elementary school'
#  'High school' 'Unknown' 'Illiterate' 'Writing & reading']
# ['Employee' 'Unknown' 'Owner' 'Other']

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12313 entries, 3 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12313 non-null  object
#  1   Day_of_week                  12313 non-null  object
#  2   Age_band_of_driver           12313 non-null  object
#  3   Sex_of_driver                12313 non-null  object
#  4   Educational_level            12313 non-null  object
#  5   Vehicle_driver_relation      12313 non-null  object
#  6   Driving_experience           12313 non-null  object
#  7   Type_of_vehicle              12313 non-null  object
#  8   Owner_of_vehicle             12313 non-null  object
#  9   Service_year_of_vehicle      12313 non-null  object
#  10  Defect_of_vehicle            12313 non-null  object
#  11  Area_accident_occured        12313 non-null  object
#  12  Lanes_or_Medians             12313 non-null  object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12313.000000          12313.000000
# mean                      2.040689              1.548039
# std                       0.688873              1.007277
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
sns.countplot(data=df,x='Accident_severity')
plt.show()

sns.countplot(data=df,x='Weather_conditions',order=df['Weather_conditions'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
sns.histplot(data=df,x='Age_band_of_driver')
plt.show()

sns.histplot(data=df,x='Types_of_Junction')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
sns.countplot(data=df,x='Age_band_of_driver',hue='Accident_severity',order=df['Age_band_of_driver'].value_counts().index)
plt.xlabel('Age band of driver')
plt.ylabel('Number of Accidents')
plt.show()

# %%
sns.countplot(data=df,x='Weather_conditions',hue='Accident_severity',order=df['Weather_conditions'].value_counts().index)
plt.xlabel('Weather conditions')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df,x='Road_surface_conditions',hue='Accident_severity',order=df['Road_surface_conditions'].value_counts().index)
plt.xlabel('Road surface conditions')
plt.ylabel('Number of Accidents')
plt.show()

# %%
sns.countplot(data=df,x='Light_conditions',hue='Accident_severity',order=df['Light_conditions'].value_counts().index)
plt.xlabel('Light conditions')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=25)
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.countplot(y='Cause_of_accident', data=df, order=df['Cause_of_accident'].value_counts().index)
plt.title('Distribution of Accidents by Cause')
plt.xlabel('Number of Accidents')
plt.ylabel('Cause of Accident')
plt.show()

sns.countplot(y='Type_of_vehicle', data=df, order=df['Type_of_vehicle'].value_counts().index)
plt.title('Distribution of Accidents by Day of the Week')
plt.xlabel('Number of Accidents')
# Out:
# Text(0.5, 0, 'Number of Accidents')

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.histplot(data=df, x='Number_of_vehicles_involved', kde=True)
plt.title('Distribution of Number of Vehicles Involved')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Density')
plt.show()

# %%
plt.bar(df['Day_of_week'].value_counts().index, df['Day_of_week'].value_counts())
plt.title('Distribution of Accidents by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.show()

# %%
plt.pie(df['Accident_severity'].value_counts(), labels=df['Accident_severity'].unique(), autopct='%1.1f%%')
plt.title('Distribution of Accidents by Severity')
plt.show()

# %%
sns.scatterplot(x='Number_of_vehicles_involved', y='Number_of_casualties', data=df)
plt.title('Relationship between Number of Vehicles Involved and Number of Casualties')
plt.xlabel('Number of Vehicles Involved')
plt.ylabel('Number of Casualties')
plt.show()

# %%
df_num = df.select_dtypes(include=[np.number])
sns.heatmap(df_num.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
# Key Insights:

# Day of the Week: Accidents are more frequent on weekends (Friday, Saturday, Sunday).
# Age of Driver: Younger drivers (18-30) and older drivers (Over 51) are more likely to be involved in severe accidents.
# Cause of Accident: The most common causes of accidents are "No distancing" and "Changing lane to the right".
# Type of Vehicle: Automobiles are involved in the majority of accidents.
# Correlation: There's a positive correlation between the number of vehicles involved and the number of casualties.

# Conclusions:

# Enhancing road safety measures during peak traffic times
# The high involvement of automobiles suggests a need to examine vehicle safety standards and driver behavior in these vehicles.
# Improving road infrastructure and implementing better traffic management systems
